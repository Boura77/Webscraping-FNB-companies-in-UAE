# %%
import requests
import pandas as pd
import bs4 as BeautifulSoup

# %%
HEAD = {'User_Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0'}

# %%
test_url = 'https://www.nrtcfresh.com/collections/fruits'

# %%
response = requests.get(test_url, headers=HEAD)

# %%
import requests

url = "https://www.nrtcfresh.com/api/v1/search/indexes/products/search"

payload = "^{^\\^filter^^:^\\^category_handle"
headers = {
    "authority": "www.nrtcfresh.com",
    "accept": "*/*",
    "accept-language": "en-US,en;q=0.9",
    "authorization": "Bearer Ic0AE3uptIkjWSEpfLj7IIyNk3jtwg8V9290jr6gq1",
    "cache-control": "no-cache",
    "content-type": "application/json",
    "cookie": "_gcl_au=1.1.1932635606.1706855854; _gid=GA1.2.444856660.1706855856; _fbp=fb.1.1706855858659.1089732371; _clck=4azj19^%^7C2^%^7Cfix^%^7C0^%^7C1493; _tt_enable_cookie=1; _ttp=gYgx8nlxufK6YS9sAqi3yduUX51; _lr_uf_-uckeud=80e4c203-88a5-4c75-8f1d-b23be5e11885; PHPSESSID=gvm70je0v4a934q4m13spjf6ss; ph_phc_XRzMxmbknbmJj86qTEqJjEzG5Rul6S5EgFGsfdzbHhK_posthog=^%^7B^%^22distinct_id^%^22^%^3A^%^22018d6889-777a-7440-ab55-b299ceba4bcc^%^22^%^2C^%^22^%^24sesid^%^22^%^3A^%^5B1706869537557^%^2C^%^22018d6939-8361-75d5-a6b7-6f24c358e970^%^22^%^2C1706867393377^%^5D^%^7D; _ga=GA1.2.1287250367.1706855855; _clsk=1go99ri^%^7C1706869538302^%^7C8^%^7C1^%^7Cq.clarity.ms^%^2Fcollect; _lr_tabs_-uckeud^%^2Fnrtcfresh-prod=^{^%^22sessionID^%^22:0^%^2C^%^22recordingID^%^22:^%^225-289b3f2a-fe99-4337-8b83-8a51b20cbb41^%^22^%^2C^%^22webViewID^%^22:null^%^2C^%^22lastActivity^%^22:1706869538391^}; private_content_version=42dc00e8733661c132a670fc7cd782c8; _lr_hb_-uckeud^%^2Fnrtcfresh-prod=^{^%^22heartbeat^%^22:1706869658852^}; _ga_MRWRTJ29FF=GS1.1.1706866571.3.1.1706870194.53.0.0",
    "origin": "https://www.nrtcfresh.com",
    "pragma": "no-cache",
    "referer": "https://www.nrtcfresh.com/collections/fruits",
    "sec-ch-ua": "^\^Not",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "^\^Windows^^",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0"
}

response = requests.request("GET", url, data=payload, headers=headers)

print(response)
data = response.json()
print(data)
# Out:
# <Response [200]>
# ...
